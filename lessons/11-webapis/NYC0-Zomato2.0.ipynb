# %% [markdown]
# ## Now You Code In Class: Where Can I Get Something to Eat?
#
# Let's write an application which uses the Zomato api https://developers.zomato.com/api to provide access to local area restaurants.
#
# The basic gist of the application will be:
#
# 1. ask for a location
# 2. ask for the type of cuisine you are interested in
# 3. output restaurant suggestions
# 4. when one is selected display the address and phone number.
#
#
# You should try to implement the following functions below. I suggest taking a **bottom-up problem solving approach**, first writing the function, testing it, and then finally using them in the main program. Remember good functions should do one thing well and have data inputs and data outputs through the return statement. They should be immutable, meaning the function does not change data but instead it returns the data back to the caller.
#
# Once you implement the functions, implement your main program. Then implement any error handling.

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Inputs: location, cuisine
#
#     select a rest.
#
# Outputs: suggestions of rest. based on location and cuisine
#
# details of my selection
#
# Algorithm (Steps in Program):
#
# 1) input location like syracuse, ny
# 2) input type of food you are interested in e.g. pizza, sushi
# 3) show restaraunt suggestions for location and cuisine
# 4) display the suggestions, allowing me to select one
# 5) based on my selection I get bad the location (address and phone number)

# %%
import requests 

zomato_key = '8a0d66c268b134b0ee4f99a66ec7af99'
#city_id of Syracuse, New York' is 988


def get_city_id(zomato_key, city_state):
    '''
        returns the first city_id in the search results, None when there are no results.
        return city_id 
    '''
    headers = { 'user-key' : zomato_key }
    params = {'q' : city_state }
    response = requests.get('https://developers.zomato.com/api/v2.1/cities', headers=headers, params=params)
    data = response.json()
    locations = data.get('location_suggestions',None)
    return locations[0]['id']
    
get_city_id(zomato_key,'Syracuse, NY')
# Out:
# 988

# %%
def search_area(zomato_key, city_id, keywords):
    '''
        returns a list of restaurants in the city_id matching keywords
        return list of restaurants 
    '''
    # todo: implement here
    my_headers = {'user-key' : zomato_key}
    my_querystring = { 'q' : keywords, 'entity_type' : 'city', 'entity_id' :city_id }
    url = 'https://developers.zomato.com/api/v2.1/search'
    response = requests.get(url, params = my_querystring, headers= my_headers)
    results = response.json()
    return results['restaurants']

search_area(zomato_key, 988, 'sushi')
# Out:
# [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643440},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643440',
#    'name': 'Sakanaya',
#    'url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '215 Walton St Ste 100, Syracuse 13202',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0479000000',
#     'longitude': '-76.1561000000',
#     'zipcode': '13202',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Sushi',
#    'timings': 'Dinner (Sun),Lunch, Dinner (Mon-Sat)',
#    'average_cost_for_two': 25,
#    'price_range': 2,
#    'currency': '$',
#    'highlights': ['Dinner', 'Lunch', 'Gluten Free Options'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=213&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': '4.4',
#     'rating_text': 'Very Good',
#     'rating_color': '5BA829',
#     'rating_obj': {'title': {'text': '4.4'},
#      'bg_color': {'type': 'lime', 'tint': '700'}},
#     'votes': '86'},
#    'all_reviews_count': 12,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 17,
#    'photos': [{'photo': {'id': 'u_Njg1Mjg1NzAyNT',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=213&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139193,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_zMyOTA1MDk1MzI',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/990/e3fde264a2cacb8e650b119cbe079990_1453139198.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/990/e3fde264a2cacb8e650b119cbe079990_1453139198.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=816&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139200,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_4NTcwNjAyMTAxN',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/04c/e010c7d68b4cb99b9d5ca73c8be8204c_1453139185.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/04c/e010c7d68b4cb99b9d5ca73c8be8204c_1453139185.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=599&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139187,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_QzNjM3MzgMjMyM',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/066/be058e77a22f595340a412c6388b6066_1453139183.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/066/be058e77a22f595340a412c6388b6066_1453139183.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=816&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139185,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_NzE1ODAxNDkwNz',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/1ad/a1df8802908a5dab50ddbd477efc31ad_1453139187.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/1ad/a1df8802908a5dab50ddbd477efc31ad_1453139187.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139189,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_xNDIzMjAwMDQ3O',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/c54/3cf244bff470d0a55cabdcd3b382ac54_1453139196.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/c54/3cf244bff470d0a55cabdcd3b382ac54_1453139196.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=370&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139198,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_TcwMTU5MzAwNzM',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/020/7646d189720051ff34932a6c504c5020_1453139193.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/020/7646d189720051ff34932a6c504c5020_1453139193.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=509&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Fullcolor',
#        'zomato_handle': 'Fullcolor',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 12,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/24533757'},
#       'res_id': 17643440,
#       'caption': '',
#       'timestamp': 1453139196,
#       'friendly_time': 'Jan 18, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_MjI3NjQ2ODQ1MD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/eea/517fb6f76dcf4076b2e2f79267a4deea.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/eea/517fb6f76dcf4076b2e2f79267a4deea.jpg?impolicy=newcropandfit&cropw=900&croph=900&cropoffsetx=78&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Cici Wang',
#        'zomato_handle': '',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 2,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/cici-wang-22766983?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/wine_2x.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/22766983'},
#       'res_id': 17643440,
#       'caption': 'Sakanaya',
#       'timestamp': 1334395512,
#       'friendly_time': 'Apr 14, 2012',
#       'width': 2048,
#       'height': 1536}},
#     {'photo': {'id': 'u_NjUzODQ1NTYwMz',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/87b/b603e9d2d574c6fcd27333607ac3c87b.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/87b/b603e9d2d574c6fcd27333607ac3c87b.jpg?impolicy=newcropandfit&cropw=900&croph=900&cropoffsetx=127&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Cici Wang',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 2,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/cici-wang-22766983?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/wine_2x.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/22766983'},
#       'res_id': 17643440,
#       'caption': 'Sakanaya',
#       'timestamp': 1334395512,
#       'friendly_time': 'Apr 14, 2012',
#       'width': 2048,
#       'height': 1536}},
#     {'photo': {'id': 'u_MzgyOTA1MTcyOT',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/f5c/6a4faf1660bc8b067084e16582b2ff5c.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/f5c/6a4faf1660bc8b067084e16582b2ff5c.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=86&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Big Hungry Shelby',
#        'zomato_handle': 'BigHungryShelby',
#        'foodie_level': 'Connoisseur',
#        'foodie_level_num': 13,
#        'foodie_color': 'e95151',
#        'profile_url': 'https://www.zomato.com/BigHungryShelby?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/240/8c8d1164922dbd670445daf21e134240.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21475148'},
#       'res_id': 17643440,
#       'caption': 'Tempura Shrimp Roll',
#       'timestamp': 1331279362,
#       'friendly_time': 'Mar 09, 2012',
#       'width': 1530,
#       'height': 2048}}],
#    'menu_url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643440',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 475-0117',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17642576},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17642576',
#    'name': 'Ichiban Japanese Steak House',
#    'url': 'https://www.zomato.com/syracuse-ny/ichiban-japanese-steak-house-liverpool?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '302 Old Liverpool Rd, Liverpool 13088',
#     'locality': 'Liverpool',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0859000000',
#     'longitude': '-76.1850000000',
#     'zipcode': '13088',
#     'country_id': 216,
#     'locality_verbose': 'Liverpool, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Japanese, Steak, Sushi',
#    'timings': '4:30 PM to 9 PM (Mon-Fri),5 PM to 10 PM (Sat),4 PM to 9 PM (Sun)',
#    'average_cost_for_two': 40,
#    'price_range': 3,
#    'currency': '$',
#    'highlights': ['Dinner',
#     'Lunch',
#     'Indoor Seating',
#     'Table booking recommended'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/132/a8eb18786d54fe7c3553ed7ce49ed132.jpg?impolicy=newcropandfit&cropw=896&croph=896&cropoffsetx=132&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': '4.5',
#     'rating_text': 'Excellent',
#     'rating_color': '3F7E00',
#     'rating_obj': {'title': {'text': '4.5'},
#      'bg_color': {'type': 'lime', 'tint': '700'}},
#     'votes': '155'},
#    'all_reviews_count': 35,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/ichiban-japanese-steak-house-liverpool/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 3,
#    'photos': [{'photo': {'id': 'u_NjgyMDY5NDMwOD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/132/a8eb18786d54fe7c3553ed7ce49ed132.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/132/a8eb18786d54fe7c3553ed7ce49ed132.jpg?impolicy=newcropandfit&cropw=896&croph=896&cropoffsetx=132&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Carmen Rosa Medina-Mohr',
#        'zomato_handle': '',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/carmen-rosa-medinamohr-22403169?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/a5b/a4fa1a585679b6d1e8f8e1b0c4649a5b.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/22403169'},
#       'res_id': 17642576,
#       'caption': 'Crystal bubble',
#       'timestamp': 1321781940,
#       'friendly_time': 'Nov 20, 2011',
#       'width': 2048,
#       'height': 1530}},
#     {'photo': {'id': 'u_MDQxMTc2MjQxNz',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/41e/52e11e6e03a31fc842d189e26cda941e.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/41e/52e11e6e03a31fc842d189e26cda941e.jpg?impolicy=newcropandfit&cropw=896&croph=896&cropoffsetx=304&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Carmen Rosa Medina-Mohr',
#        'zomato_handle': '',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/carmen-rosa-medinamohr-22403169?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/a5b/a4fa1a585679b6d1e8f8e1b0c4649a5b.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/22403169'},
#       'res_id': 17642576,
#       'caption': 'Ichiban Japanese Steak House',
#       'timestamp': 1321781940,
#       'friendly_time': 'Nov 20, 2011',
#       'width': 2048,
#       'height': 1530}},
#     {'photo': {'id': 'u_MTk2MTg0MjY0MD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/359/43a6b6ac9cdd5088cd2ef23d14409359.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/359/43a6b6ac9cdd5088cd2ef23d14409359.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=403&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Shyley',
#        'foodie_level': 'Big Foodie',
#        'foodie_level_num': 4,
#        'foodie_color': 'ffae4f',
#        'profile_url': 'https://www.zomato.com/users/shyley-21457713?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/572/17a840d64591660029aed01c935af572.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21457713'},
#       'res_id': 17642576,
#       'caption': 'Steak, Scallops, Shrimp',
#       'timestamp': 1329551057,
#       'friendly_time': 'Feb 18, 2012',
#       'width': 1224,
#       'height': 2048}}],
#    'menu_url': 'https://www.zomato.com/syracuse-ny/ichiban-japanese-steak-house-liverpool/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/132/a8eb18786d54fe7c3553ed7ce49ed132.jpg',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17642576',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/ichiban-japanese-steak-house-liverpool/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 457-0000',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643769},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643769',
#    'name': 'Koto Japanese Steakhouse',
#    'url': 'https://www.zomato.com/syracuse-ny/koto-japanese-steakhouse-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '2841 Erie Blvd. East, Syracuse 13224',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0552340000',
#     'longitude': '-76.0930360000',
#     'zipcode': '13224',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Japanese, Sushi',
#    'timings': 'Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)',
#    'average_cost_for_two': 40,
#    'price_range': 3,
#    'currency': '$',
#    'highlights': ['Lunch',
#     'Takeaway Available',
#     'Dinner',
#     'Indoor Seating',
#     'Table booking recommended'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': '',
#    'user_rating': {'aggregate_rating': '3.9',
#     'rating_text': 'Good',
#     'rating_color': '9ACD32',
#     'rating_obj': {'title': {'text': '3.9'},
#      'bg_color': {'type': 'lime', 'tint': '600'}},
#     'votes': '52'},
#    'all_reviews_count': 21,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/koto-japanese-steakhouse-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 0,
#    'menu_url': 'https://www.zomato.com/syracuse-ny/koto-japanese-steakhouse-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': '',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643769',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/koto-japanese-steakhouse-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 445-5686',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643634},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643634',
#    'name': 'Oishi Sushi',
#    'url': 'https://www.zomato.com/syracuse-ny/oishi-sushi-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '713 South Crouse Avenue, Syracuse 13210',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0424630000',
#     'longitude': '-76.1364410000',
#     'zipcode': '13210',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Sushi',
#    'timings': '',
#    'average_cost_for_two': 10,
#    'price_range': 1,
#    'currency': '$',
#    'highlights': ['Delivery', 'Lunch', 'Takeaway Available', 'Dinner'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': '',
#    'user_rating': {'aggregate_rating': '3.5',
#     'rating_text': 'Good',
#     'rating_color': '9ACD32',
#     'rating_obj': {'title': {'text': '3.5'},
#      'bg_color': {'type': 'lime', 'tint': '500'}},
#     'votes': '15'},
#    'all_reviews_count': 6,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/oishi-sushi-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 0,
#    'menu_url': 'https://www.zomato.com/syracuse-ny/oishi-sushi-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': '',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643634',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/oishi-sushi-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 849-1305',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17642883},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17642883',
#    'name': 'Bleu Monkey Cafe',
#    'url': 'https://www.zomato.com/syracuse-ny/bleu-monkey-cafe-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '163 Marshall St, Syracuse 13210',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0415958000',
#     'longitude': '-76.1351185000',
#     'zipcode': '13210',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Japanese, Sushi',
#    'timings': '5 PM to 9:30 PM (Mon-Sun)',
#    'average_cost_for_two': 25,
#    'price_range': 2,
#    'currency': '$',
#    'highlights': ['Delivery', 'Lunch', 'Takeaway Available', 'Dinner'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/e5d/cc52810c5d3559fb04bab25b82527e5d_1453247072.jpg?impolicy=newcropandfit&cropw=2042&croph=2042&cropoffsetx=64&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': '3.9',
#     'rating_text': 'Good',
#     'rating_color': '9ACD32',
#     'rating_obj': {'title': {'text': '3.9'},
#      'bg_color': {'type': 'lime', 'tint': '600'}},
#     'votes': '15'},
#    'all_reviews_count': 2,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/bleu-monkey-cafe-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 3,
#    'photos': [{'photo': {'id': 'u_xNzQyMzQ5MDE1M',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/e5d/cc52810c5d3559fb04bab25b82527e5d_1453247072.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/e5d/cc52810c5d3559fb04bab25b82527e5d_1453247072.jpg?impolicy=newcropandfit&cropw=2042&croph=2042&cropoffsetx=64&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Ashley Simone',
#        'zomato_handle': 'AshOnPoint',
#        'foodie_level': 'Super Foodie',
#        'foodie_level_num': 10,
#        'foodie_color': 'f58552',
#        'profile_url': 'https://www.zomato.com/AshOnPoint?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/341/e2600315f71d0ab7a174f7f413fd5341.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/31484590'},
#       'res_id': 17642883,
#       'caption': '',
#       'timestamp': 1453247073,
#       'friendly_time': 'Jan 20, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_DYxNTIyNzE2Mzg',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/d42/0d96f67dafafda0309c0ed46aea20d42_1453247076.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/d42/0d96f67dafafda0309c0ed46aea20d42_1453247076.jpg?impolicy=newcropandfit&cropw=3024&croph=3024&cropoffsetx=0&cropoffsety=861&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Ashley Simone',
#        'zomato_handle': 'AshOnPoint',
#        'foodie_level': 'Super Foodie',
#        'foodie_level_num': 10,
#        'foodie_color': 'f58552',
#        'profile_url': 'https://www.zomato.com/AshOnPoint?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/341/e2600315f71d0ab7a174f7f413fd5341.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/31484590'},
#       'res_id': 17642883,
#       'caption': '',
#       'timestamp': 1453247079,
#       'friendly_time': 'Jan 20, 2016',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_5OTk4ODA2OTE3M',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/c0d/c88a089fdd3e2747936cf05c88798c0d_1453247071.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/c0d/c88a089fdd3e2747936cf05c88798c0d_1453247071.jpg?impolicy=newcropandfit&cropw=1847&croph=1847&cropoffsetx=174&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Ashley Simone',
#        'zomato_handle': 'AshOnPoint',
#        'foodie_level': 'Super Foodie',
#        'foodie_level_num': 10,
#        'foodie_color': 'f58552',
#        'profile_url': 'https://www.zomato.com/AshOnPoint?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/341/e2600315f71d0ab7a174f7f413fd5341.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/31484590'},
#       'res_id': 17642883,
#       'caption': '',
#       'timestamp': 1453247072,
#       'friendly_time': 'Jan 20, 2016',
#       'width': 640,
#       'height': 640}}],
#    'menu_url': 'https://www.zomato.com/syracuse-ny/bleu-monkey-cafe-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/e5d/cc52810c5d3559fb04bab25b82527e5d_1453247072.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17642883',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/bleu-monkey-cafe-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 474-0099',
#    'all_reviews': {'reviews': [{'review': []}, {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643330},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643330',
#    'name': 'New Ling Ling Chinese Buffet',
#    'url': 'https://www.zomato.com/syracuse-ny/new-ling-ling-chinese-buffet-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '604 S Main St, Syracuse 13212',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.1251000000',
#     'longitude': '-76.1393000000',
#     'zipcode': '13212',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Chinese, Sushi',
#    'timings': 'Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)',
#    'average_cost_for_two': 25,
#    'price_range': 2,
#    'currency': '$',
#    'highlights': ['Lunch', 'Dinner'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': '',
#    'user_rating': {'aggregate_rating': '4.1',
#     'rating_text': 'Very Good',
#     'rating_color': '5BA829',
#     'rating_obj': {'title': {'text': '4.1'},
#      'bg_color': {'type': 'lime', 'tint': '700'}},
#     'votes': '33'},
#    'all_reviews_count': 17,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/new-ling-ling-chinese-buffet-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 0,
#    'menu_url': 'https://www.zomato.com/syracuse-ny/new-ling-ling-chinese-buffet-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': '',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643330',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/new-ling-ling-chinese-buffet-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 458-9800',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643848},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643848',
#    'name': 'Namu Restaurant & Bar',
#    'url': 'https://www.zomato.com/syracuse-ny/namu-restaurant-bar-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '215 Walton St., Syracuse 13202',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0478754000',
#     'longitude': '-76.1562618000',
#     'zipcode': '13202',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Chinese, Sushi',
#    'timings': '(Sun),Lunch, Dinner (Mon-Sat)',
#    'average_cost_for_two': 40,
#    'price_range': 3,
#    'currency': '$',
#    'highlights': ['Dinner', 'Lunch', 'Gluten Free Options'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/2e3/103159b4150d9315c24e88a541c262e3.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=286&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': '3.3',
#     'rating_text': 'Average',
#     'rating_color': 'CDD614',
#     'rating_obj': {'title': {'text': '3.3'},
#      'bg_color': {'type': 'lime', 'tint': '500'}},
#     'votes': '7'},
#    'all_reviews_count': 3,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/namu-restaurant-bar-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 2,
#    'photos': [{'photo': {'id': 'u_MzgwOTg3OTYxOD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/2e3/103159b4150d9315c24e88a541c262e3.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/2e3/103159b4150d9315c24e88a541c262e3.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=286&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Matt And Rae',
#        'zomato_handle': '',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/matt-and-rae-23497909?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/23497909'},
#       'res_id': 17643848,
#       'caption': 'Namu Restaurant &amp; Bar Korean food',
#       'timestamp': 1362734253,
#       'friendly_time': 'Mar 08, 2013',
#       'width': 1536,
#       'height': 2048}},
#     {'photo': {'id': 'u_OTM0NjIzNjc1MT',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/478/886cd3d6cec19b3790076ae3b0278478.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/478/886cd3d6cec19b3790076ae3b0278478.jpg?impolicy=newcropandfit&cropw=547&croph=547&cropoffsetx=369&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'CJ',
#        'foodie_level': 'Big Foodie',
#        'foodie_level_num': 4,
#        'foodie_color': 'ffae4f',
#        'profile_url': 'https://www.zomato.com/users/cj-22511628?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/images/user_avatars/mug_2x.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/22511628'},
#       'res_id': 17643848,
#       'caption': 'Namu Restaurant &amp; Bar',
#       'timestamp': 1333280530,
#       'friendly_time': 'Apr 01, 2012',
#       'width': 2048,
#       'height': 933}}],
#    'menu_url': 'https://www.zomato.com/syracuse-ny/namu-restaurant-bar-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/2e3/103159b4150d9315c24e88a541c262e3.jpg',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643848',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/namu-restaurant-bar-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 475-0220',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643728},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643728',
#    'name': 'Ocean Sushi',
#    'url': 'https://www.zomato.com/syracuse-ny/ocean-sushi-liverpool?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '7567 oswego rd, Liverpool 13090',
#     'locality': 'Liverpool',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.1371470000',
#     'longitude': '-76.2258140000',
#     'zipcode': '13090',
#     'country_id': 216,
#     'locality_verbose': 'Liverpool, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Sushi',
#    'timings': 'Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)',
#    'average_cost_for_two': 40,
#    'price_range': 3,
#    'currency': '$',
#    'highlights': ['Lunch', 'Dinner'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/e0c/dfaa230eceb13d5a14be748eee9ffe0c.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=521&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': '4.5',
#     'rating_text': 'Excellent',
#     'rating_color': '3F7E00',
#     'rating_obj': {'title': {'text': '4.5'},
#      'bg_color': {'type': 'lime', 'tint': '700'}},
#     'votes': '33'},
#    'all_reviews_count': 13,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/ocean-sushi-liverpool/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 7,
#    'photos': [{'photo': {'id': 'u_NjU0NzQ5MTg1MD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/e0c/dfaa230eceb13d5a14be748eee9ffe0c.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/e0c/dfaa230eceb13d5a14be748eee9ffe0c.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=521&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'VictoryGin',
#        'zomato_handle': '',
#        'foodie_level': 'Super Foodie',
#        'foodie_level_num': 8,
#        'foodie_color': 'f58552',
#        'profile_url': 'https://www.zomato.com/users/victorygin-22090771?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/200/0292c097155991e879d886b71285f200.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/22090771'},
#       'res_id': 17643728,
#       'caption': 'Work of art',
#       'timestamp': 1346634262,
#       'friendly_time': 'Sep 03, 2012',
#       'width': 1224,
#       'height': 2048}},
#     {'photo': {'id': 'u_OTIwNzY0Nzk3NT',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/efd/27db27953c8bb7bbf2560a23be1a8efd.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/efd/27db27953c8bb7bbf2560a23be1a8efd.jpg?impolicy=newcropandfit&cropw=480&croph=480&cropoffsetx=0&cropoffsety=128&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Justin Lymner',
#        'foodie_level': 'Big Foodie',
#        'foodie_level_num': 6,
#        'foodie_color': 'ffae4f',
#        'profile_url': 'https://www.zomato.com/users/justin-lymner-20907630?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/eb6/e7e6f918d3da7582236520876f1dceb6.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/20907630'},
#       'res_id': 17643728,
#       'caption': 'Avocado salad',
#       'timestamp': 1278543580,
#       'friendly_time': 'Jul 08, 2010',
#       'width': 480,
#       'height': 640}},
#     {'photo': {'id': 'u_ODg0NTg4NTE0ND',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/626/b9ccfa3e5df179c79c6eb44713a7b626.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/626/b9ccfa3e5df179c79c6eb44713a7b626.jpg?impolicy=newcropandfit&cropw=900&croph=900&cropoffsetx=155&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Kari Anne Carr',
#        'zomato_handle': '',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 3,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/kari-anne-carr-21530147?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/85f/f74a27245f383de3d0b61ae8afa0b85f.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21530147'},
#       'res_id': 17643728,
#       'caption': 'Ocean Sushi',
#       'timestamp': 1294065179,
#       'friendly_time': 'Jan 03, 2011',
#       'width': 2048,
#       'height': 1536}},
#     {'photo': {'id': 'u_NDYzMzMzMTE3MD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/10b/60f6a7fd55b890beae49a2e217f3910b.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/10b/60f6a7fd55b890beae49a2e217f3910b.jpg?impolicy=newcropandfit&cropw=480&croph=480&cropoffsetx=0&cropoffsety=43&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Justin Lymner',
#        'foodie_level': 'Big Foodie',
#        'foodie_level_num': 6,
#        'foodie_color': 'ffae4f',
#        'profile_url': 'https://www.zomato.com/users/justin-lymner-20907630?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/eb6/e7e6f918d3da7582236520876f1dceb6.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/20907630'},
#       'res_id': 17643728,
#       'caption': 'Avocado rolls',
#       'timestamp': 1278543581,
#       'friendly_time': 'Jul 08, 2010',
#       'width': 480,
#       'height': 640}},
#     {'photo': {'id': 'u_NjMzNDA3MTk3Mj',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/79d/4d5f6ab6b33c020fbae787a530e8a79d.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/79d/4d5f6ab6b33c020fbae787a530e8a79d.jpg?impolicy=newcropandfit&cropw=480&croph=480&cropoffsetx=0&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Justin Lymner',
#        'zomato_handle': '',
#        'foodie_level': 'Big Foodie',
#        'foodie_level_num': 6,
#        'foodie_color': 'ffae4f',
#        'profile_url': 'https://www.zomato.com/users/justin-lymner-20907630?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/eb6/e7e6f918d3da7582236520876f1dceb6.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/20907630'},
#       'res_id': 17643728,
#       'caption': 'Ocean Sushi',
#       'timestamp': 1278543580,
#       'friendly_time': 'Jul 08, 2010',
#       'width': 480,
#       'height': 640}},
#     {'photo': {'id': 'u_MzY5MjQ2MTEyMT',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/653/b55ce7051eeecc034297f9d31f9b2653.jpg',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/653/b55ce7051eeecc034297f9d31f9b2653.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=244&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Kari Anne Carr',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 3,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/kari-anne-carr-21530147?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/85f/f74a27245f383de3d0b61ae8afa0b85f.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21530147'},
#       'res_id': 17643728,
#       'caption': 'Ocean Sushi',
#       'timestamp': 1294065179,
#       'friendly_time': 'Jan 03, 2011',
#       'width': 1536,
#       'height': 2048}}],
#    'menu_url': 'https://www.zomato.com/syracuse-ny/ocean-sushi-liverpool/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/e0c/dfaa230eceb13d5a14be748eee9ffe0c.jpg',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643728',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/ocean-sushi-liverpool/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 622-6050',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643984},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643984',
#    'name': 'Nikkou Japan',
#    'url': 'https://www.zomato.com/syracuse-ny/nikkou-japan-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '3800 West Genesee, Syracuse 13219',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0470950000',
#     'longitude': '-76.2400620000',
#     'zipcode': '13219',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Sushi, Vegetarian',
#    'timings': '11 AM to 10 PM (Mon-Thu),11 AM to 10:30 PM (Fri-Sat),Closed (Sun)',
#    'average_cost_for_two': 25,
#    'price_range': 2,
#    'currency': '$',
#    'highlights': ['Lunch',
#     'Serves Alcohol',
#     'Delivery',
#     'Dinner',
#     'Outdoor Seating',
#     'Wifi',
#     'Kid Friendly'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/007/32fcd498a6db79ed033984ac8a426007.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': '3.6',
#     'rating_text': 'Good',
#     'rating_color': '9ACD32',
#     'rating_obj': {'title': {'text': '3.6'},
#      'bg_color': {'type': 'lime', 'tint': '600'}},
#     'votes': '11'},
#    'all_reviews_count': 8,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/nikkou-japan-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 1,
#    'photos': [{'photo': {'id': 'u_MTg4OTIwNTcyMj',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/007/32fcd498a6db79ed033984ac8a426007.jpg',
# ...
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/club-sushi-and-steaks-at-mohegan-manor-baldwinsville/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 857-0080',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643857},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643857',
#    'name': 'Asian Garden',
#    'url': 'https://www.zomato.com/syracuse-ny/asian-garden-liverpool?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '7873 Oswego Road, Liverpool 13090',
#     'locality': 'Liverpool',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.1516682000',
#     'longitude': '-76.2290673000',
#     'zipcode': '13090',
#     'country_id': 216,
#     'locality_verbose': 'Liverpool, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Asian, Chinese, Sushi',
#    'timings': 'Lunch, Dinner (Sun, Mon, Tue, Wed, Thu, Fri, Sat)',
#    'average_cost_for_two': 10,
#    'price_range': 1,
#    'currency': '$',
#    'highlights': ['Delivery', 'Dinner', 'Lunch'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': '',
#    'user_rating': {'aggregate_rating': '3.6',
#     'rating_text': 'Good',
#     'rating_color': '9ACD32',
#     'rating_obj': {'title': {'text': '3.6'},
#      'bg_color': {'type': 'lime', 'tint': '600'}},
#     'votes': '4'},
#    'all_reviews_count': 4,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/asian-garden-liverpool/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 0,
#    'menu_url': 'https://www.zomato.com/syracuse-ny/asian-garden-liverpool/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': '',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643857',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/asian-garden-liverpool/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 652-8899',
#    'all_reviews': {'reviews': [{'review': []},
#      {'review': []},
#      {'review': []},
#      {'review': []}]},
#    'establishment': [],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17643942},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17643942',
#    'name': 'Asahi Japanese Restaurant',
#    'url': 'https://www.zomato.com/syracuse-ny/asahi-japanese-restaurant-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '508 Westcott St, Syracuse 13210',
#     'locality': 'Syracuse',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0416853000',
#     'longitude': '-76.1194970000',
#     'zipcode': '13210',
#     'country_id': 216,
#     'locality_verbose': 'Syracuse, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Japanese, Sushi',
#    'timings': '',
#    'average_cost_for_two': 25,
#    'price_range': 2,
#    'currency': '$',
#    'highlights': ['Delivery',
#     'Lunch',
#     'Cash',
#     'Debit Card',
#     'Takeaway Available',
#     'Dinner',
#     'Credit Card',
#     'No Alcohol Available',
#     'Indoor Seating'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': '',
#    'user_rating': {'aggregate_rating': '3.3',
#     'rating_text': 'Average',
#     'rating_color': 'CDD614',
#     'rating_obj': {'title': {'text': '3.3'},
#      'bg_color': {'type': 'lime', 'tint': '500'}},
#     'votes': '2'},
#    'all_reviews_count': 1,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/asahi-japanese-restaurant-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 0,
#    'menu_url': 'https://www.zomato.com/syracuse-ny/asahi-japanese-restaurant-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': '',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17643942',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/asahi-japanese-restaurant-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 424-8818',
#    'all_reviews': {'reviews': [{'review': []}]},
#    'establishment': ['Casual Dining'],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 18323713},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '18323713',
#    'name': 'Mitsuba Japanese Cuisine',
#    'url': 'https://www.zomato.com/syracuse-ny/mitsuba-japanese-cuisine-camillus?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '174 Township Boulevard Ste 10 13031',
#     'locality': 'Camillus',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.0467500000',
#     'longitude': '-76.2666900000',
#     'zipcode': '13031',
#     'country_id': 216,
#     'locality_verbose': 'Camillus, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Japanese, Sushi',
#    'timings': '11:30 AM to 10 PM (Mon-Thu), 11:30 AM to 11 PM (Fri), 12 Noon to 11 PM (Sat), 12 Noon to 9:30 PM (Sun)',
#    'average_cost_for_two': 0,
#    'price_range': 1,
#    'currency': '$',
#    'highlights': ['Cash',
#     'Debit Card',
#     'Takeaway Available',
#     'Lunch',
#     'Credit Card',
#     'Delivery',
#     'Dinner',
#     'Outdoor Seating',
#     'Wifi',
#     'Apple Pay',
#     'Private Parking',
#     'Indoor Seating',
#     'Fullbar'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': '',
#    'user_rating': {'aggregate_rating': 0,
#     'rating_text': 'Not rated',
#     'rating_color': 'CBCBCB',
#     'rating_obj': {'title': {'text': '-'},
#      'bg_color': {'type': 'grey', 'tint': '400'}},
#     'votes': 1},
#    'all_reviews_count': 0,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/mitsuba-japanese-cuisine-camillus/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 0,
#    'menu_url': 'https://www.zomato.com/syracuse-ny/mitsuba-japanese-cuisine-camillus/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': '',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/18323713',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/mitsuba-japanese-cuisine-camillus/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 488-8898',
#    'all_reviews': {'reviews': []},
#    'establishment': ['Casual Dining'],
#    'establishment_types': []}},
#  {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 17644007},
#    'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#    'id': '17644007',
#    'name': 'Mohegan Manor Restaurant & Club Sushi',
#    'url': 'https://www.zomato.com/syracuse-ny/mohegan-manor-restaurant-club-sushi-baldwinsville?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': '58 Oswego St, Baldwinsville 13027',
#     'locality': 'Baldwinsville',
#     'city': 'Syracuse',
#     'city_id': 988,
#     'latitude': '43.1594210000',
#     'longitude': '-76.3325420000',
#     'zipcode': '13027',
#     'country_id': 216,
#     'locality_verbose': 'Baldwinsville, Syracuse'},
#    'switch_to_order_menu': 0,
#    'cuisines': '',
#    'timings': '4:30 PM to 10 PM (Mon-Wed),4:30 PM to 11 PM (Thu-Sat),Closed (Sun)',
#    'average_cost_for_two': 0,
#    'price_range': 1,
#    'currency': '$',
#    'highlights': ['Lunch', 'Dinner'],
#    'offers': [],
#    'opentable_support': 0,
#    'is_zomato_book_res': 0,
#    'mezzo_provider': 'OTHER',
#    'is_book_form_web_view': 0,
#    'book_form_web_view_url': '',
#    'book_again_url': '',
#    'thumb': 'https://b.zmtcdn.com/data/reviews_photos/33e/b57f122f57fbaba7855464ed66a2f33e_1440438721.jpg?impolicy=newcropandfit&cropw=800&croph=800&cropoffsetx=154&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#    'user_rating': {'aggregate_rating': 0,
#     'rating_text': 'Not rated',
#     'rating_color': 'CBCBCB',
#     'rating_obj': {'title': {'text': '-'},
#      'bg_color': {'type': 'grey', 'tint': '400'}},
#     'votes': 2},
#    'all_reviews_count': 0,
#    'photos_url': 'https://www.zomato.com/syracuse-ny/mohegan-manor-restaurant-club-sushi-baldwinsville/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#    'photo_count': 5,
#    'photos': [{'photo': {'id': 'u_4ODYxNzI5Mzg1M',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/33e/b57f122f57fbaba7855464ed66a2f33e_1440438721.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/33e/b57f122f57fbaba7855464ed66a2f33e_1440438721.jpg?impolicy=newcropandfit&cropw=800&croph=800&cropoffsetx=154&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Dennis Sick',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/dennis-sick-21026622?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8bb/714910d230a17bbacd2740b1e48bd8bb.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21026622'},
#       'res_id': 17644007,
#       'caption': 'Lounge At Mohegan Manor',
#       'timestamp': 1440438743,
#       'friendly_time': 'Aug 24, 2015',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_DY3OTkNjY5MDA3',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/22a/66e584191e39538a40c15d4af767c22a_1440438950.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/22a/66e584191e39538a40c15d4af767c22a_1440438950.jpg?impolicy=newcropandfit&cropw=682&croph=682&cropoffsetx=293&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Dennis Sick',
#        'zomato_handle': '',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/dennis-sick-21026622?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8bb/714910d230a17bbacd2740b1e48bd8bb.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21026622'},
#       'res_id': 17644007,
#       'caption': 'Green Room at Mohegan Manor',
#       'timestamp': 1440438978,
#       'friendly_time': 'Aug 24, 2015',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_MTg3NgOTM5MzI1',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/838/c2c8c32807affdc8079267326494e838_1440438632.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/838/c2c8c32807affdc8079267326494e838_1440438632.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Dennis Sick',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/dennis-sick-21026622?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8bb/714910d230a17bbacd2740b1e48bd8bb.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21026622'},
#       'res_id': 17644007,
#       'caption': 'Historic Ward Wellington Ward Facility',
#       'timestamp': 1440438674,
#       'friendly_time': 'Aug 24, 2015',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_DY3NTU4OTA0NzY',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/a16/6eae912865faa4a36f5e9d377eb37a16_1440438817.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/a16/6eae912865faa4a36f5e9d377eb37a16_1440438817.jpg?impolicy=newcropandfit&cropw=900&croph=900&cropoffsetx=66&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Dennis Sick',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/dennis-sick-21026622?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8bb/714910d230a17bbacd2740b1e48bd8bb.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21026622'},
#       'res_id': 17644007,
#       'caption': 'Ballroom at Mohegan Manor',
#       'timestamp': 1440438836,
#       'friendly_time': 'Aug 24, 2015',
#       'width': 640,
#       'height': 640}},
#     {'photo': {'id': 'u_ODU1MTU0MjY5MD',
#       'url': 'https://b.zmtcdn.com/data/reviews_photos/95a/e310c20fe80691d7c1b7419fcc08995a_1440438883.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#       'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/95a/e310c20fe80691d7c1b7419fcc08995a_1440438883.jpg?impolicy=newcropandfit&cropw=686&croph=686&cropoffsetx=0&cropoffsety=44&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#       'user': {'name': 'Dennis Sick',
#        'foodie_level': 'Foodie',
#        'foodie_level_num': 1,
#        'foodie_color': 'ffd35d',
#        'profile_url': 'https://www.zomato.com/users/dennis-sick-21026622?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#        'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/8bb/714910d230a17bbacd2740b1e48bd8bb.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#        'profile_deeplink': 'zomato://u/21026622'},
#       'res_id': 17644007,
#       'caption': 'Reception Area at Mohegan Manor',
#       'timestamp': 1440438901,
#       'friendly_time': 'Aug 24, 2015',
#       'width': 640,
#       'height': 640}}],
#    'menu_url': 'https://www.zomato.com/syracuse-ny/mohegan-manor-restaurant-club-sushi-baldwinsville/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#    'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/33e/b57f122f57fbaba7855464ed66a2f33e_1440438721.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#    'has_online_delivery': 0,
#    'is_delivering_now': 0,
#    'store_type': '',
#    'include_bogo_offers': True,
#    'deeplink': 'zomato://restaurant/17644007',
#    'is_table_reservation_supported': 0,
#    'has_table_booking': 0,
#    'events_url': 'https://www.zomato.com/syracuse-ny/mohegan-manor-restaurant-club-sushi-baldwinsville/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'phone_numbers': '(315) 857-0079',
#    'all_reviews': {'reviews': []},
#    'establishment': [],
#    'establishment_types': []}}]

# %%
def restaurant_details(zomato_key, rest_id):
    '''
        returns a details of a restaurant given the rest_id 
        return on success: {'status' : 'ok', 'message' : 'ok', 'details' : details }
        return on failure: {'status' : 'error', 'message' : 'Reason for failure.', 'details' : None }
    '''
    # todo: implement here
    my_headers = { 'user-key' : zomato_key }
    my_querystring = { 'res_id' : rest_id }
    url = 'https://developers.zomato.com/api/v2.1/restaurant'
    response = requests.get(url, params = my_querystring, headers= my_headers)
    results = response.json()
    return results
    
    
restaurant_details(zomato_key, '17643440')
# Out:
# {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#   'res_id': 17643440},
#  'apikey': '8a0d66c268b134b0ee4f99a66ec7af99',
#  'id': '17643440',
#  'name': 'Sakanaya',
#  'url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#  'location': {'address': '215 Walton St Ste 100, Syracuse 13202',
#   'locality': 'Syracuse',
#   'city': 'Syracuse',
#   'city_id': 988,
#   'latitude': '43.0479000000',
#   'longitude': '-76.1561000000',
#   'zipcode': '13202',
#   'country_id': 216,
#   'locality_verbose': 'Syracuse, Syracuse'},
#  'switch_to_order_menu': 0,
#  'cuisines': 'Asian, Sushi',
#  'timings': 'Dinner (Sun),Lunch, Dinner (Mon-Sat)',
#  'average_cost_for_two': 25,
#  'price_range': 2,
#  'currency': '$',
#  'highlights': ['Dinner', 'Lunch', 'Gluten Free Options'],
#  'offers': [],
#  'opentable_support': 0,
#  'is_zomato_book_res': 0,
#  'mezzo_provider': 'OTHER',
#  'is_book_form_web_view': 0,
#  'book_form_web_view_url': '',
#  'book_again_url': '',
#  'thumb': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=213&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#  'user_rating': {'aggregate_rating': '4.4',
#   'rating_text': 'Very Good',
#   'rating_color': '5BA829',
#   'rating_obj': {'title': {'text': '4.4'},
#    'bg_color': {'type': 'lime', 'tint': '700'}},
#   'votes': '86'},
#  'all_reviews_count': 12,
#  'photos_url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#  'photo_count': 17,
#  'photos': [{'photo': {'id': 'u_Njg1Mjg1NzAyNT',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=213&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139193,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_zMyOTA1MDk1MzI',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/990/e3fde264a2cacb8e650b119cbe079990_1453139198.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/990/e3fde264a2cacb8e650b119cbe079990_1453139198.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=816&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139200,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_4NTcwNjAyMTAxN',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/04c/e010c7d68b4cb99b9d5ca73c8be8204c_1453139185.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/04c/e010c7d68b4cb99b9d5ca73c8be8204c_1453139185.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=599&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139187,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_QzNjM3MzgMjMyM',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/066/be058e77a22f595340a412c6388b6066_1453139183.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/066/be058e77a22f595340a412c6388b6066_1453139183.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=816&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139185,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_NzE1ODAxNDkwNz',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/1ad/a1df8802908a5dab50ddbd477efc31ad_1453139187.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/1ad/a1df8802908a5dab50ddbd477efc31ad_1453139187.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=0&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139189,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_xNDIzMjAwMDQ3O',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/c54/3cf244bff470d0a55cabdcd3b382ac54_1453139196.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/c54/3cf244bff470d0a55cabdcd3b382ac54_1453139196.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=370&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139198,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_TcwMTU5MzAwNzM',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/020/7646d189720051ff34932a6c504c5020_1453139193.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/020/7646d189720051ff34932a6c504c5020_1453139193.jpg?impolicy=newcropandfit&cropw=2448&croph=2448&cropoffsetx=509&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Fullcolor',
#      'zomato_handle': 'Fullcolor',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 12,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/Fullcolor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/cupcake.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/24533757'},
#     'res_id': 17643440,
#     'caption': '',
#     'timestamp': 1453139196,
#     'friendly_time': 'Jan 18, 2016',
#     'width': 640,
#     'height': 640}},
#   {'photo': {'id': 'u_MjI3NjQ2ODQ1MD',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/eea/517fb6f76dcf4076b2e2f79267a4deea.jpg',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/eea/517fb6f76dcf4076b2e2f79267a4deea.jpg?impolicy=newcropandfit&cropw=900&croph=900&cropoffsetx=78&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Cici Wang',
#      'foodie_level': 'Foodie',
#      'foodie_level_num': 2,
#      'foodie_color': 'ffd35d',
#      'profile_url': 'https://www.zomato.com/users/cici-wang-22766983?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/wine_2x.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/22766983'},
#     'res_id': 17643440,
#     'caption': 'Sakanaya',
#     'timestamp': 1334395512,
#     'friendly_time': 'Apr 14, 2012',
#     'width': 2048,
#     'height': 1536}},
#   {'photo': {'id': 'u_NjUzODQ1NTYwMz',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/87b/b603e9d2d574c6fcd27333607ac3c87b.jpg',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/87b/b603e9d2d574c6fcd27333607ac3c87b.jpg?impolicy=newcropandfit&cropw=900&croph=900&cropoffsetx=127&cropoffsety=0&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Cici Wang',
#      'zomato_handle': '',
#      'foodie_level': 'Foodie',
#      'foodie_level_num': 2,
#      'foodie_color': 'ffd35d',
#      'profile_url': 'https://www.zomato.com/users/cici-wang-22766983?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/images/user_avatars/wine_2x.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/22766983'},
#     'res_id': 17643440,
#     'caption': 'Sakanaya',
#     'timestamp': 1334395512,
#     'friendly_time': 'Apr 14, 2012',
#     'width': 2048,
#     'height': 1536}},
#   {'photo': {'id': 'u_MzgyOTA1MTcyOT',
#     'url': 'https://b.zmtcdn.com/data/reviews_photos/f5c/6a4faf1660bc8b067084e16582b2ff5c.jpg',
#     'thumb_url': 'https://b.zmtcdn.com/data/reviews_photos/f5c/6a4faf1660bc8b067084e16582b2ff5c.jpg?impolicy=newcropandfit&cropw=1200&croph=1200&cropoffsetx=0&cropoffsety=86&cropgravity=NorthWest&fitw=200&fith=200&fittype=ignore',
#     'user': {'name': 'Big Hungry Shelby',
#      'zomato_handle': 'BigHungryShelby',
#      'foodie_level': 'Connoisseur',
#      'foodie_level_num': 13,
#      'foodie_color': 'e95151',
#      'profile_url': 'https://www.zomato.com/BigHungryShelby?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/240/8c8d1164922dbd670445daf21e134240.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/21475148'},
#     'res_id': 17643440,
#     'caption': 'Tempura Shrimp Roll',
#     'timestamp': 1331279362,
#     'friendly_time': 'Mar 09, 2012',
#     'width': 1530,
#     'height': 2048}}],
#  'menu_url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#  'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/b36/063175dd27ba82cfc77aa17d918bfb36_1453139191.jpg?fit=around%7C640%3A640&crop=640%3A640%3B%2A%2C%2A',
#  'has_online_delivery': 0,
#  'is_delivering_now': 0,
#  'store_type': '',
#  'include_bogo_offers': True,
#  'deeplink': 'zomato://restaurant/17643440',
#  'is_table_reservation_supported': 0,
#  'has_table_booking': 0,
#  'events_url': 'https://www.zomato.com/syracuse-ny/sakanaya-syracuse/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#  'phone_numbers': '(315) 475-0117',
#  'all_reviews': {'reviews': [{'review': []},
#    {'review': []},
#    {'review': []},
#    {'review': []},
#    {'review': []}]},
#  'establishment': []}

# %%
from IPython.display import display, HTML, Image
location = input("Enter a location: ")
cuisine = input("Enter a cuisine: ")
city_id = get_city_id(zomato_key, location)
search_results = search_area(zomato_key, city_id, cuisine)
print("Here are the restaurants I found:")
for item in search_results:
    print(f"{item['restaurant']['id']} ===> {item['restaurant']['name']}" )
rest_id = input("Enter the Restaurant ID and I will give you more details: ")
details = restaurant_details(zomato_key, rest_id)
display(HTML(f"<h1>{details['name']}</h1>"))
display(HTML(f"<p><b>Address:</b> {details['location']['address']}<p>"))
display(HTML(f"<p><b>Phone  :</b> {details['phone_numbers']}<p>"))
# Out:
# Enter a location: Albany, GA
# Enter a cuisine: Cajun
# Here are the restaurants I found:
# 17286070 ===> Hattie's Restaurant
# 17287327 ===> Hattie's Chicken Shack
# 17286050 ===> Esperanto
# 17287866 ===> Parish Public House
# 17287184 ===> Grahams Lansingbugh Cafe
# 17284565 ===> Cajun Cafe & Grill
# 17287715 ===> Nanola
# 17287641 ===> Fitzy's Fork in the Road
# 17284564 ===> Cajun Cafe
# 17286027 ===> Cajun Cafe & Grill
# Enter the Restaurant ID and I will give you more details: 17286070
# <h1>Hattie's Restaurant</h1>
# <p><b>Address:</b> 45 Phila Street 12866<p>
# <p><b>Phone  :</b> (518) 584-4790<p>

# %%
# Out:
# ('Twin Trees III', '310 N Main St, North Syracuse 13212', '(315) 458-9311')

# %%
3) show restaraunt suggestions for location and cuisine
4) display the suggestions, allowing me to select one
5) based on my selection I get bad the location (address and phone number)
